# %%
from pymongo import MongoClient

password = "moksh0001"
uri = f"mongodb+srv://moksh:{password}@cluster0.6ty3pnm.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri)

# %%
client.list_database_names()
# Out:
# ['medicine_db', 'resume_analyzer', 'admin', 'local']

# %%
db = client["medicine_db"]
db.list_collection_names()
# Out:
# ['users', 'medicines', 'oct_medicines']

# %%
for doc in db["oct_medicines"].find().limit(2):
    print(doc)
# Out:
# {'_id': ObjectId('68dcc9e9b8daa3becbb5ada3'), 'Batch_ID': 'BATCH_1', 'Name of Medicine': 'Paracetamol 500mg', 'Category': 'Antipyretics', 'Medicine Forms': 'Tablet', 'Price_INR': 20, 'Quantity_per_pack': '10 Tablets', 'Total_Quantity': 1152, 'Cover Disease': 'Fever, Headache', 'Symptoms': 'High fever, body ache, headache', 'Side Effects': 'Nausea, rash, liver damage in overdose', 'Instructions': 'Take 1 tablet every 6-8 hours, preferably after food, with 1 glass of water (200ml), avoid alcohol, no heavy physical activity for 1 hour after taking, rest recommended, do not exceed 4 tablets in 24 hours.', 'Description in Hinglish': 'Yeh dawa fever ko kam karti hai aur dard se relief deti hai, commonly used for sardi-zukam.'}
# {'_id': ObjectId('68dcc9e9b8daa3becbb5ada4'), 'Batch_ID': 'BATCH_2', 'Name of Medicine': 'Ibuprofen 400mg', 'Category': 'Antipyretics', 'Medicine Forms': 'Tablet', 'Price_INR': 30, 'Quantity_per_pack': '15 Tablets', 'Total_Quantity': 1512, 'Cover Disease': 'Fever, Inflammation', 'Symptoms': 'Fever with pain, joint swelling', 'Side Effects': 'Stomach upset, heartburn, dizziness', 'Instructions': 'Take 1 tablet every 8 hours with food, drink with 250ml water, avoid driving if dizzy, no alcohol, light activity okay but rest if possible, strictly avoid if ulcer history.', 'Description in Hinglish': 'Yeh medicine swelling aur fever ko reduce karta hai, arthritis jaise conditions mein helpful.'}

# %%
collection = db["oct_medicines"]
docs = list(collection.find({}))

# %%
import pandas as pd
df = pd.DataFrame(docs)
df.head(2)
# Out:
#                         _id Batch_ID   Name of Medicine      Category  \
# 0  68dcc9e9b8daa3becbb5ada3  BATCH_1  Paracetamol 500mg  Antipyretics
# 1  68dcc9e9b8daa3becbb5ada4  BATCH_2    Ibuprofen 400mg  Antipyretics
#
#   Medicine Forms  Price_INR Quantity_per_pack  Total_Quantity  \
# 0         Tablet         20        10 Tablets            1152
# 1         Tablet         30        15 Tablets            1512
#
#          Cover Disease                         Symptoms  \
# 0      Fever, Headache  High fever, body ache, headache
# 1  Fever, Inflammation  Fever with pain, joint swelling
#
#                              Side Effects  \
# 0  Nausea, rash, liver damage in overdose
# 1     Stomach upset, heartburn, dizziness
#
#                                         Instructions  \
# 0  Take 1 tablet every 6-8 hours, preferably afte...
# 1  Take 1 tablet every 8 hours with food, drink w...
#
#                              Description in Hinglish
# 0  Yeh dawa fever ko kam karti hai aur dard se re...
# 1  Yeh medicine swelling aur fever ko reduce kart...

# %%
df.isnull().sum()
# Out:
# _id                        0
# Batch_ID                   0
# Name of Medicine           0
# Category                   0
# Medicine Forms             0
# Price_INR                  0
# Quantity_per_pack          0
# Total_Quantity             0
# Cover Disease              0
# Symptoms                   0
# Side Effects               0
# Instructions               0
# Description in Hinglish    0
# dtype: int64

# %%
df = df.drop("_id", axis=1)
df.head(2)
# Out:
#   Batch_ID   Name of Medicine      Category Medicine Forms  Price_INR  \
# 0  BATCH_1  Paracetamol 500mg  Antipyretics         Tablet         20
# 1  BATCH_2    Ibuprofen 400mg  Antipyretics         Tablet         30
#
#   Quantity_per_pack  Total_Quantity        Cover Disease  \
# 0        10 Tablets            1152      Fever, Headache
# 1        15 Tablets            1512  Fever, Inflammation
#
#                           Symptoms                            Side Effects  \
# 0  High fever, body ache, headache  Nausea, rash, liver damage in overdose
# 1  Fever with pain, joint swelling     Stomach upset, heartburn, dizziness
#
#                                         Instructions  \
# 0  Take 1 tablet every 6-8 hours, preferably afte...
# 1  Take 1 tablet every 8 hours with food, drink w...
#
#                              Description in Hinglish
# 0  Yeh dawa fever ko kam karti hai aur dard se re...
# 1  Yeh medicine swelling aur fever ko reduce kart...

# %%
df.columns
# Out:
# Index(['Batch_ID', 'Name of Medicine', 'Category', 'Medicine Forms',
#        'Price_INR', 'Quantity_per_pack', 'Total_Quantity', 'Cover Disease',
#        'Symptoms', 'Side Effects', 'Instructions', 'Description in Hinglish'],
#       dtype='object')

# %%
df["filter_2"] = (
    "Category: " + df["Category"].astype(str) + " | " +
    "Symptoms: " + df["Symptoms"].astype(str) + " | " +
    "Cover Disease: " + df["Cover Disease"].astype(str)
)

# %%
df.filter_2[0]
# Out:
# 'Category: Antipyretics | Symptoms: High fever, body ache, headache | Cover Disease: Fever, Headache'

# %%
df["filter_3"] = df["Description in Hinglish"]

# %%
df.filter_3[0]
# Out:
# 'Yeh dawa fever ko kam karti hai aur dard se relief deti hai, commonly used for sardi-zukam.'

# %%
df.to_excel("medicine_data_filter_2_3.xlsx")

# %%
# from sentence_transformers import SentenceTransformer
# import pandas as pd
# import numpy as np
# import torch
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model = SentenceTransformer("intfloat/multilingual-e5-base", device=device)

# # Generate embeddings on GPU
# embeddings = model.encode(
#     df["filter_3"].tolist(),
#     show_progress_bar=True,
#     convert_to_numpy=True,
#     device=device
# )

# # Store in dataframe
# df["embedding_filter_3"] = embeddings.tolist()

# # Save for reuse
# df.to_parquet("/content/drive/MyDrive/Colab Notebooks/ChatBot Deva/medicine_with_filter_3.parquet", index=False)
# print("✅ Embeddings done & saved on Colab GPU")

# %%
import numpy as np
dfe = pd.read_parquet("embedding files/medicine_with_both_filters.parquet")
embeddings1 = np.array(dfe["embedding_filter_2"].tolist())
print("✅ Loaded embeddings:", embeddings1.shape)
# Out:
# ✅ Loaded embeddings: (1350, 768)

# %%
dfe.head(2)
# Out:
#    Unnamed: 0 Batch_ID   Name of Medicine      Category Medicine Forms  \
# 0           0  BATCH_1  Paracetamol 500mg  Antipyretics         Tablet
# 1           1  BATCH_2    Ibuprofen 400mg  Antipyretics         Tablet
#
#    Price_INR Quantity_per_pack  Total_Quantity        Cover Disease  \
# 0         20        10 Tablets            1152      Fever, Headache
# 1         30        15 Tablets            1512  Fever, Inflammation
#
#                           Symptoms                            Side Effects  \
# 0  High fever, body ache, headache  Nausea, rash, liver damage in overdose
# 1  Fever with pain, joint swelling     Stomach upset, heartburn, dizziness
#
#                                         Instructions  \
# 0  Take 1 tablet every 6-8 hours, preferably afte...
# 1  Take 1 tablet every 8 hours with food, drink w...
#
#                              Description in Hinglish  \
# 0  Yeh dawa fever ko kam karti hai aur dard se re...
# 1  Yeh medicine swelling aur fever ko reduce kart...
#
#                                             filter_2  \
# 0  Category: Antipyretics | Symptoms: High fever,...
# 1  Category: Antipyretics | Symptoms: Fever with ...
#
#                                             filter_3  \
# 0  Yeh dawa fever ko kam karti hai aur dard se re...
# 1  Yeh medicine swelling aur fever ko reduce kart...
#
#                                   embedding_filter_2  \
# 0  [-0.0005164753529243171, 0.010079099796712399,...
# 1  [0.011730153113603592, 0.027518214657902718, -...
#
#                                   embedding_filter_3
# 0  [0.023296838626265526, 0.05303220450878143, 0....
# 1  [0.01389602292329073, 0.0374966561794281, -0.0...

# %%
dim1 = embeddings1.shape[1]
dim1
# Out:
# 768

# %%
import faiss
index1 = faiss.IndexFlatL2(dim1)
index1
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x0000015B241A9C80> >

# %%
index1.add(embeddings1)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("intfloat/multilingual-e5-base")
# Out:
# WARNING:tensorflow:From C:\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def collect_data_for_filter_2(search_query):
    vec = model.encode(search_query)
    svec = np.array(vec).reshape(1,-1)
    distance , I = index1.search(svec , k=3)
    result = dfe.loc[I[0]]
    return result

# %%
collect_data_for("Bleeding stoping medicines")
# Out:
#       Unnamed: 0    Batch_ID     Name of Medicine        Category  \
# 1203        1203  BATCH_1204      Vitamin K1 10mg       Antidotes
# 291          291   BATCH_292  Argatroban 100mg/ml  Anticoagulants
# 1176        1176  BATCH_1177  Fresh Frozen Plasma  Blood Products
#
#      Medicine Forms  Price_INR Quantity_per_pack  Total_Quantity  \
# 1203      Injection         50         1 Ampoule            1159
# 291       Injection       1000            1 Vial             396
# 1176    Transfusion       1200            1 Unit             675
#
#                          Cover Disease            Symptoms       Side Effects  \
# 1203                          Bleeding          Hemorrhage        Anaphylaxis
# 291   Heparin-Induced Thrombocytopenia  Bruising, bleeding   Bleeding, low BP
# 1176                      Coagulopathy            Bleeding  Allergic reaction
#
#                                            Instructions  \
# 1203                              IV slow, monitor INR.
# 291   Administered via IV in hospital, rest, monitor...
# 1176                   Thaw before use, ABG compatible.
#
#                                 Description in Hinglish  \
# 1203                     Yeh warfarin reversal ke liye.
# 291   Yeh injection acute clotting disorders ke liye...
# 1176                     Yeh clotting factors deta hai.
#
#                                                filter_2  \
# 1203  Category: Antidotes | Symptoms: Hemorrhage | C...
# 291   Category: Anticoagulants | Symptoms: Bruising,...
# 1176  Category: Blood Products | Symptoms: Bleeding ...
#
#                                                filter_3  \
# 1203                     Yeh warfarin reversal ke liye.
# 291   Yeh injection acute clotting disorders ke liye...
# 1176                     Yeh clotting factors deta hai.
#
#                                      embedding_filter_2  \
# 1203  [0.004850052297115326, 0.04550952836871147, -0...
# 291   [0.02665327489376068, 0.04707089066505432, -0....
# 1176  [0.023751724511384964, 0.03259950876235962, -0...
#
#                                      embedding_filter_3
# 1203  [0.027626773342490196, 0.029239444062113762, 0...
# 291   [0.00774384243413806, 0.054503943771123886, 0....
# 1176  [0.009719204157590866, 0.040091317147016525, 0...

# %%
embeddings2 = np.array(dfe["embedding_filter_3"].tolist())
print("✅ Loaded embeddings:", embeddings2.shape)
# Out:
# ✅ Loaded embeddings: (1350, 768)

# %%
dim2 = embeddings2.shape[1]
dim2
# Out:
# 768

# %%
import faiss
index2 = faiss.IndexFlatL2(dim2)
index2
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x0000015B241BF4E0> >

# %%
index2.add(embeddings2)

# %%
def collect_data_for_filter_3(search_query):
    vec = model.encode(search_query)
    svec = np.array(vec).reshape(1,-1)
    distance , I = index2.search(svec , k=3)
    result = dfe.loc[I[0]]
    return result

# %%
collect_data_for_filter_3("stomach pain kr raha h bhai")
# Out:
#      Unnamed: 0   Batch_ID             Name of Medicine        Category  \
# 678         678  BATCH_679   Hyoscine Butylbromide 10mg  Antispasmodics
# 639         639  BATCH_640  Bismuth Subsalicylate 525mg  Antidiarrheals
# 645         645  BATCH_646  Diphenoxylate-Bismuth Combo  Antidiarrheals
#
#       Medicine Forms  Price_INR Quantity_per_pack  Total_Quantity  \
# 678           Tablet         40        10 Tablets            1258
# 639  Chewable Tablet         40        10 Tablets            1982
# 645           Tablet         55        10 Tablets            1267
#
#                Cover Disease              Symptoms  \
# 678         Abdominal Cramps  Stomach pain, spasms
# 639  Diarrhea, Upset Stomach  Loose stools, nausea
# 645  Diarrhea, Upset Stomach  Loose stools, nausea
#
#                    Side Effects  \
# 678        Dry mouth, dizziness
# 639  Black tongue, constipation
# 645    Drowsiness, black tongue
#
#                                           Instructions  \
# 678  Take 1 tablet thrice daily, with 200ml water, ...
# 639  Chew 2 tablets every 4 hours, with 100ml water...
# 645  Take 1 tablet every 6 hours, with 200ml water,...
#
#                                Description in Hinglish  \
# 678  Yeh antispasmodic stomach aur intestinal cramp...
# 639  Yeh antidiarrheal stomach upset aur diarrhea k...
# 645  Yeh combo diarrhea aur stomach upset ke liye hai.
#
#                                               filter_2  \
# 678  Category: Antispasmodics | Symptoms: Stomach p...
# 639  Category: Antidiarrheals | Symptoms: Loose sto...
# 645  Category: Antidiarrheals | Symptoms: Loose sto...
#
#                                               filter_3  \
# 678  Yeh antispasmodic stomach aur intestinal cramp...
# 639  Yeh antidiarrheal stomach upset aur diarrhea k...
# 645  Yeh combo diarrhea aur stomach upset ke liye hai.
#
#                                     embedding_filter_2  \
# 678  [0.01960654743015766, 0.05751660838723183, -0....
# 639  [0.015198037959635258, 0.04340919107198715, -0...
# 645  [0.015198037959635258, 0.04340919107198715, -0...
#
#                                     embedding_filter_3
# 678  [0.011113454587757587, 0.06888478994369507, 0....
# 639  [-1.9844252165057696e-05, 0.052971940487623215...
# 645  [0.018971692770719528, 0.05300415679812431, 0....

# %%
def search_medicine(content):
    exclude_cols = ["Medicine Forms", "Price_INR", "Quantity_per_pack", "Total_Quantity"]
    search_cols = [col for col in df.columns if col not in exclude_cols]
    mask = df[search_cols].apply(lambda row: row.astype(str).str.contains(content, case=False, na=False), axis=1).any(axis=1)
    result = df[mask]

    if result.empty:
        print("Nope 😕 No records found.")
    else:
        print(f"✅ Found {len(result)} record(s):")
        return result

# %%
search_medicine("BATCH_1345")
# Out:
# ✅ Found 1 record(s):
#         Batch_ID  Name of Medicine               Category Medicine Forms  \
# 1344  BATCH_1345  Domperidone 10mg  Digestive & Laxatives         Tablet
#
#       Price_INR Quantity_per_pack  Total_Quantity  Cover Disease  Symptoms  \
# 1344         25        10 Tablets             654  Gastroparesis  Bloating
#
#      Side Effects                                      Instructions  \
# 1344    Dry mouth  Take 1 tablet thrice daily, 30 min before meals.
#
#                      Description in Hinglish  \
# 1344  Yeh prokinetic hai, digestion improve.
#
#                                                filter_2  \
# 1344  Category: Digestive & Laxatives | Symptoms: Bl...
#
#                                     filter_3
# 1344  Yeh prokinetic hai, digestion improve.

# %%
from rapidfuzz import fuzz

def search_medicine_pipeline(search_query, top_k=15, fuzzy_threshold=60, vector_threshold=0.6):
    results = pd.DataFrame()
    
    # --- Filter 1: Fuzzy search ---
    exclude_cols = ["Medicine Forms", "Price_INR", "Quantity_per_pack", "Total_Quantity"]
    search_cols = [col for col in df.columns if col not in exclude_cols]

    def fuzzy_score(row):
        return max([fuzz.partial_ratio(str(val), search_query) for val in row])
    
    df['fuzzy_score'] = df[search_cols].apply(fuzzy_score, axis=1)
    result1 = df[df['fuzzy_score'] >= fuzzy_threshold]
    
    results = pd.concat([results, result1])
    
    # --- Vector filters ---
    vec = model.encode(search_query)
    svec = np.array(vec).reshape(1, -1)

    # Filter 2
    distances2, indices2 = index1.search(svec, k=10)
    relevant_indices2 = [i for i, d in zip(indices2[0], distances2[0]) if d >= vector_threshold]
    result2 = dfe.loc[relevant_indices2]
    result2['vector_score'] = [distances2[0][i] for i in range(len(relevant_indices2))]
    
    # Filter 3
    distances3, indices3 = index2.search(svec, k=10)
    relevant_indices3 = [i for i, d in zip(indices3[0], distances3[0]) if d >= vector_threshold]
    result3 = dfe.loc[relevant_indices3]
    result3['vector_score'] = [distances3[0][i] for i in range(len(relevant_indices3))]
    
    results = pd.concat([results, result2, result3])
    
    # --- Remove duplicates ---
    results = results.drop_duplicates().reset_index(drop=True)
    
    # --- Calculate combined relevance score ---
    results['relevance_score'] = results.get('fuzzy_score', 0) + results.get('vector_score', 0)
    
    # --- Sort and limit results ---
    results = results.sort_values(by='relevance_score', ascending=False).head(top_k)
    
    print(f"✅ Showing top {len(results)} most relevant medicines for || {search_query} ")
    return results.drop(columns=['fuzzy_score', 'vector_score'])

# %%
test_samples = [
    "High fever and headache, need a quick medicine",
    "Child fever, mild cold, which syrup is good?",
    "Severe body ache and fever, tablet suggestion",
    "Joint pain with inflammation, want something fast",
    "Period pain and fever, what should I take?",
    "Fever with nausea and fatigue, recommend medicine",
    "Mild headache, occasional fever, safe for children",
    "Strong fever with chills, need tablet immediately",
    "Persistent low-grade fever, best medicine for adults",
    "Acute fever onset with body weakness, which tablet?",
    "Swelling in joints with fever, suggest capsule",
    "Red joints and inflammation with fever, help me choose",
    "Stomach upset after fever, what tablet is okay?",
    "Teething pain with fever in kids, syrup suggestion",
    "Hangover with fever and nausea, recommend medicine",
    "Chronic fever, taking other medicines, safe option?",
    "Fever and muscular pain, want relief quickly",
    "Headache with high fever, need something effective",
    "Fever and cramps during period, which medicine works?",
    "Sudden fever, mild headache, safe over-the-counter options"
]
print(len(test_samples))
test_samples[0]
# Out:
# 20
# 'High fever and headache, need a quick medicine'

# %%
search_medicine_pipeline(test_samples[18])
# Out:
# ✅ Showing top 15 most relevant medicines for || Fever and cramps during period, which medicine works?
#     Batch_ID      Name of Medicine      Category         Medicine Forms  \
# 0    BATCH_1     Paracetamol 500mg  Antipyretics                 Tablet
# 1    BATCH_3         Aspirin 325mg  Antipyretics                 Tablet
# 2    BATCH_6  Mefenamic Acid 500mg  Antipyretics                Capsule
# 3    BATCH_7      Combiflam Tablet  Antipyretics                 Tablet
# 4    BATCH_9        Saridon Tablet  Antipyretics                 Tablet
# 5   BATCH_10           Sumo Tablet  Antipyretics                 Tablet
# 6   BATCH_12           Advil 200mg  Antipyretics                Capsule
# 7   BATCH_13        Disprin Tablet  Antipyretics    Effervescent Tablet
# 8   BATCH_17         Ecosprin 75mg  Antipyretics  Enteric Coated Tablet
# 9   BATCH_18      Zerodol P Tablet  Antipyretics                 Tablet
# 10  BATCH_19        Crocin Advance  Antipyretics                 Tablet
# 11  BATCH_20        Piroxicam 20mg  Antipyretics                Capsule
# 12  BATCH_84    Ketoconazole 200mg   Antifungals                 Tablet
# 13  BATCH_92      Caspofungin 50mg   Antifungals              Injection
# 14  BATCH_95    Luliconazole Cream   Antifungals                  Cream
#
#     Price_INR Quantity_per_pack  Total_Quantity          Cover Disease  \
# 0          20        10 Tablets            1152        Fever, Headache
# 1          15        10 Tablets            1902       Fever, Mild Pain
# 2          35       10 Capsules             488  Fever, Menstrual Pain
# 3          25        10 Tablets             971       Fever, Body Ache
# 4          18        10 Tablets            1906        Fever, Headache
# 5          45        10 Tablets            1568             High Fever
# 6          50       20 Capsules            1363         Fever, Sprains
# 7          10        10 Tablets             595        Fever, Hangover
# 8          15        14 Tablets            1370             Mild Fever
# 9          30        10 Tablets             853          Fever, Spasms
# 10         25        15 Tablets            1821            Acute Fever
# 11         40       10 Capsules             997      Fever, Joint Pain
# 12        100        10 Tablets             324   Systemic Candidiasis
# 13       2000            1 Vial            1115             Candidemia
# 14        120          15g Tube             562               Ringworm
#
#                            Symptoms  \
# 0   High fever, body ache, headache
# 1     Fever, mild headache, fatigue
# 2       Fever with cramps, headache
# 3            High fever, joint pain
# 4     Pulsating headache with fever
# 5              Severe fever, chills
# 6               Fever with swelling
# 7                     Fever, nausea
# 8       Low fever, chest discomfort
# 9                 Fever with cramps
# 10               Sudden fever onset
# 11             Fever with stiffness
# 12             Fever, fatigue, rash
# 13              Fever, chills, rash
# 14             Red circular patches
#
#                                          Side Effects  \
# 0              Nausea, rash, liver damage in overdose
# 1   Gastric irritation, bleeding risk, allergic re...
# 2                 Diarrhea, abdominal pain, dizziness
# 3                       Nausea, vomiting, indigestion
# 4                               Drowsiness, dry mouth
# 5                                  Stomach pain, rash
# 6                                Heartburn, dizziness
# 7                             Gastric upset, tinnitus
# 8                              Bleeding, stomach pain
# 9                               Drowsiness, dry mouth
# 10                            Rare allergic reactions
# 11                                 GI bleeding, edema
# 12                               Liver issues, nausea
# 13                                Fever, nausea, rash
# 14                              Mild burning, itching
#
#                                          Instructions  \
# 0   Take 1 tablet every 6-8 hours, preferably afte...
# 1   Take 1 tablet daily or as needed, dissolve in ...
# 2   Take 1 capsule every 8 hours after food, swall...
# 3   Take 1 tablet every 6 hours, with 250ml water ...
# 4   Take 1 tablet as needed, up to 3 per day, with...
# 5   Take 1 tablet every 12 hours, with food and 30...
# 6   Take 1-2 capsules every 4-6 hours, with 200ml ...
# 7   Dissolve 1 tablet in 100ml water, take every 8...
# 8   Take 1 tablet daily in morning, with 200ml wat...
# 9   Take 1 tablet every 8 hours, with 250ml water ...
# 10  Take 1 tablet every 4 hours as needed, with 20...
# 11  Take 1 capsule daily, with food and 300ml wate...
# 12  Take 1 tablet daily with food, 200ml water, av...
# 13  Administered via IV once daily in hospital, st...
# 14  Apply once daily on affected area, clean and d...
#
#                               Description in Hinglish  \
# 0   Yeh dawa fever ko kam karti hai aur dard se re...
# 1   Yeh dawa fever aur heart problems ke liye use ...
# 2   Yeh dawa period pain aur fever ke liye best ha...
# 3   Yeh combo dawa fever aur severe pain ko handle...
# 4   Yeh headache aur fever ke liye fast acting daw...
# 5   Yeh strong dawa fever aur pain ke liye hai, bu...
# 6   Yeh ibuprofen based hai jo fever aur minor inj...
# 7   Yeh aspirin effervescent form mein hai, fever ...
# 8   Yeh low dose aspirin fever prevention aur hear...
# 9   Yeh combo dawa fever aur muscle pain ko target...
# 10     Yeh fast acting paracetamol fever ke liye hai.
# 11  Yeh NSAID dawa fever aur arthritis pain mein u...
# 12  Yeh dawa serious fungal infections ke liye hai...
# 13  Yeh invasive fungal infections ke liye hospita...
# 14  Yeh modern antifungal cream hai, ringworm aur ...
#
#                                              filter_2  \
# 0   Category: Antipyretics | Symptoms: High fever,...
# 1   Category: Antipyretics | Symptoms: Fever, mild...
# 2   Category: Antipyretics | Symptoms: Fever with ...
# 3   Category: Antipyretics | Symptoms: High fever,...
# 4   Category: Antipyretics | Symptoms: Pulsating h...
# 5   Category: Antipyretics | Symptoms: Severe feve...
# 6   Category: Antipyretics | Symptoms: Fever with ...
# 7   Category: Antipyretics | Symptoms: Fever, naus...
# 8   Category: Antipyretics | Symptoms: Low fever, ...
# 9   Category: Antipyretics | Symptoms: Fever with ...
# 10  Category: Antipyretics | Symptoms: Sudden feve...
# 11  Category: Antipyretics | Symptoms: Fever with ...
# 12  Category: Antifungals | Symptoms: Fever, fatig...
# 13  Category: Antifungals | Symptoms: Fever, chill...
# 14  Category: Antifungals | Symptoms: Red circular...
#
#                                              filter_3  Unnamed: 0  \
# 0   Yeh dawa fever ko kam karti hai aur dard se re...         NaN
# 1   Yeh dawa fever aur heart problems ke liye use ...         NaN
# 2   Yeh dawa period pain aur fever ke liye best ha...         NaN
# 3   Yeh combo dawa fever aur severe pain ko handle...         NaN
# 4   Yeh headache aur fever ke liye fast acting daw...         NaN
# 5   Yeh strong dawa fever aur pain ke liye hai, bu...         NaN
# 6   Yeh ibuprofen based hai jo fever aur minor inj...         NaN
# 7   Yeh aspirin effervescent form mein hai, fever ...         NaN
# 8   Yeh low dose aspirin fever prevention aur hear...         NaN
# 9   Yeh combo dawa fever aur muscle pain ko target...         NaN
# 10     Yeh fast acting paracetamol fever ke liye hai.         NaN
# 11  Yeh NSAID dawa fever aur arthritis pain mein u...         NaN
# 12  Yeh dawa serious fungal infections ke liye hai...         NaN
# 13  Yeh invasive fungal infections ke liye hospita...         NaN
# 14  Yeh modern antifungal cream hai, ringworm aur ...         NaN
#
#    embedding_filter_2 embedding_filter_3  relevance_score
# 0                 NaN                NaN              NaN
# 1                 NaN                NaN              NaN
# 2                 NaN                NaN              NaN
# 3                 NaN                NaN              NaN
# 4                 NaN                NaN              NaN
# 5                 NaN                NaN              NaN
# 6                 NaN                NaN              NaN
# 7                 NaN                NaN              NaN
# 8                 NaN                NaN              NaN
# 9                 NaN                NaN              NaN
# 10                NaN                NaN              NaN
# 11                NaN                NaN              NaN
# 12                NaN                NaN              NaN
# 13                NaN                NaN              NaN
# 14                NaN                NaN              NaN

# %%
from rapidfuzz import fuzz
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss

# ---------------------- Load Data & Embeddings ----------------------
dfe = pd.read_parquet("embedding files/medicine_with_both_filters.parquet")

# Embeddings for vector search
embeddings1 = np.array(dfe["embedding_filter_2"].tolist())
print("✅ Loaded embeddings1:", embeddings1.shape)
embeddings2 = np.array(dfe["embedding_filter_3"].tolist())
print("✅ Loaded embeddings2:", embeddings2.shape)

# Build FAISS indexes
dim1 = embeddings1.shape[1]
dim2 = embeddings2.shape[1]

index1 = faiss.IndexFlatL2(dim1)
index2 = faiss.IndexFlatL2(dim2)

index1.add(embeddings1)
index2.add(embeddings2)

# Load multilingual sentence transformer
model = SentenceTransformer("intfloat/multilingual-e5-base")
print(f"Model Load {model}")

# ---------------------- Search Pipeline ----------------------
def search_medicine_pipeline(search_query, top_k=15, fuzzy_threshold=60, vector_threshold=0.6):
    results = pd.DataFrame()
    
    # --- Fuzzy search ---
    exclude_cols = ["Medicine Forms", "Price_INR", "Quantity_per_pack", "Total_Quantity",
                    "embedding_filter_2", "embedding_filter_3"]
    search_cols = [col for col in dfe.columns if col not in exclude_cols]

    def fuzzy_score(row):
        return max([fuzz.partial_ratio(str(val), search_query) for val in row])
    
    dfe['fuzzy_score'] = dfe[search_cols].apply(fuzzy_score, axis=1)
    result1 = dfe[dfe['fuzzy_score'] >= fuzzy_threshold].copy()
    results = pd.concat([results, result1])
    
    # --- Vector search ---
    vec = model.encode(search_query)
    svec = np.array(vec).reshape(1, -1)

    # Filter 2
    distances2, indices2 = index1.search(svec, k=10)
    relevant_indices2 = [i for i, d in zip(indices2[0], distances2[0]) if d >= vector_threshold]
    result2 = dfe.loc[relevant_indices2].copy()
    result2['vector_score'] = [distances2[0][i] for i in range(len(relevant_indices2))]
    
    # Filter 3
    distances3, indices3 = index2.search(svec, k=10)
    relevant_indices3 = [i for i, d in zip(indices3[0], distances3[0]) if d >= vector_threshold]
    result3 = dfe.loc[relevant_indices3].copy()
    result3['vector_score'] = [distances3[0][i] for i in range(len(relevant_indices3))]
    
    # --- Combine results ---
    results = pd.concat([results, result2, result3])
    
    # --- Safe deduplication using Batch_ID ---
    results = results.drop_duplicates(subset=['Batch_ID']).reset_index(drop=True)
    
    # --- Normalize scores ---
    if 'fuzzy_score' in results:
        results['fuzzy_score_norm'] = results['fuzzy_score'] / 100
    else:
        results['fuzzy_score_norm'] = 0
    if 'vector_score' in results:
        results['vector_score_norm'] = results['vector_score'] / results['vector_score'].max()
    else:
        results['vector_score_norm'] = 0
    
    # --- Combined relevance ---
    results['relevance_score'] = results['fuzzy_score_norm'] + results['vector_score_norm']
    
    # --- Sort by combined score and limit top_k ---
    results = results.sort_values(by='relevance_score', ascending=False).head(top_k)
    
    print(f"✅ Showing top {len(results)} most relevant medicines for || {search_query}")
    
    # Drop helper columns before returning
    return results.drop(columns=['fuzzy_score', 'vector_score', 'fuzzy_score_norm', 'vector_score_norm'])
# Out:
# ✅ Loaded embeddings1: (1350, 768)
# ✅ Loaded embeddings2: (1350, 768)
# Model Load SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: XLMRobertaModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
search_medicine_pipeline(test_samples[18])
# Out:
# ✅ Showing top 15 most relevant medicines for || Fever and cramps during period, which medicine works?
#     Unnamed: 0  Batch_ID      Name of Medicine      Category  \
# 0            0   BATCH_1     Paracetamol 500mg  Antipyretics
# 1            2   BATCH_3         Aspirin 325mg  Antipyretics
# 2            5   BATCH_6  Mefenamic Acid 500mg  Antipyretics
# 3            6   BATCH_7      Combiflam Tablet  Antipyretics
# 4            8   BATCH_9        Saridon Tablet  Antipyretics
# 5            9  BATCH_10           Sumo Tablet  Antipyretics
# 6           11  BATCH_12           Advil 200mg  Antipyretics
# 7           12  BATCH_13        Disprin Tablet  Antipyretics
# 8           16  BATCH_17         Ecosprin 75mg  Antipyretics
# 9           17  BATCH_18      Zerodol P Tablet  Antipyretics
# 10          18  BATCH_19        Crocin Advance  Antipyretics
# 11          19  BATCH_20        Piroxicam 20mg  Antipyretics
# 12          83  BATCH_84    Ketoconazole 200mg   Antifungals
# 13          91  BATCH_92      Caspofungin 50mg   Antifungals
# 14          94  BATCH_95    Luliconazole Cream   Antifungals
#
#            Medicine Forms  Price_INR Quantity_per_pack  Total_Quantity  \
# 0                  Tablet         20        10 Tablets            1152
# 1                  Tablet         15        10 Tablets            1902
# 2                 Capsule         35       10 Capsules             488
# 3                  Tablet         25        10 Tablets             971
# 4                  Tablet         18        10 Tablets            1906
# 5                  Tablet         45        10 Tablets            1568
# 6                 Capsule         50       20 Capsules            1363
# 7     Effervescent Tablet         10        10 Tablets             595
# 8   Enteric Coated Tablet         15        14 Tablets            1370
# 9                  Tablet         30        10 Tablets             853
# 10                 Tablet         25        15 Tablets            1821
# 11                Capsule         40       10 Capsules             997
# 12                 Tablet        100        10 Tablets             324
# 13              Injection       2000            1 Vial            1115
# 14                  Cream        120          15g Tube             562
#
#             Cover Disease                         Symptoms  \
# 0         Fever, Headache  High fever, body ache, headache
# 1        Fever, Mild Pain    Fever, mild headache, fatigue
# 2   Fever, Menstrual Pain      Fever with cramps, headache
# 3        Fever, Body Ache           High fever, joint pain
# 4         Fever, Headache    Pulsating headache with fever
# 5              High Fever             Severe fever, chills
# 6          Fever, Sprains              Fever with swelling
# 7         Fever, Hangover                    Fever, nausea
# 8              Mild Fever      Low fever, chest discomfort
# 9           Fever, Spasms                Fever with cramps
# 10            Acute Fever               Sudden fever onset
# 11      Fever, Joint Pain             Fever with stiffness
# 12   Systemic Candidiasis             Fever, fatigue, rash
# 13             Candidemia              Fever, chills, rash
# 14               Ringworm             Red circular patches
#
#                                          Side Effects  \
# 0              Nausea, rash, liver damage in overdose
# 1   Gastric irritation, bleeding risk, allergic re...
# 2                 Diarrhea, abdominal pain, dizziness
# 3                       Nausea, vomiting, indigestion
# 4                               Drowsiness, dry mouth
# 5                                  Stomach pain, rash
# 6                                Heartburn, dizziness
# 7                             Gastric upset, tinnitus
# 8                              Bleeding, stomach pain
# 9                               Drowsiness, dry mouth
# 10                            Rare allergic reactions
# 11                                 GI bleeding, edema
# 12                               Liver issues, nausea
# 13                                Fever, nausea, rash
# 14                              Mild burning, itching
#
#                                          Instructions  \
# 0   Take 1 tablet every 6-8 hours, preferably afte...
# 1   Take 1 tablet daily or as needed, dissolve in ...
# 2   Take 1 capsule every 8 hours after food, swall...
# 3   Take 1 tablet every 6 hours, with 250ml water ...
# 4   Take 1 tablet as needed, up to 3 per day, with...
# 5   Take 1 tablet every 12 hours, with food and 30...
# 6   Take 1-2 capsules every 4-6 hours, with 200ml ...
# 7   Dissolve 1 tablet in 100ml water, take every 8...
# 8   Take 1 tablet daily in morning, with 200ml wat...
# 9   Take 1 tablet every 8 hours, with 250ml water ...
# 10  Take 1 tablet every 4 hours as needed, with 20...
# 11  Take 1 capsule daily, with food and 300ml wate...
# 12  Take 1 tablet daily with food, 200ml water, av...
# 13  Administered via IV once daily in hospital, st...
# 14  Apply once daily on affected area, clean and d...
#
#                               Description in Hinglish  \
# 0   Yeh dawa fever ko kam karti hai aur dard se re...
# 1   Yeh dawa fever aur heart problems ke liye use ...
# 2   Yeh dawa period pain aur fever ke liye best ha...
# 3   Yeh combo dawa fever aur severe pain ko handle...
# 4   Yeh headache aur fever ke liye fast acting daw...
# 5   Yeh strong dawa fever aur pain ke liye hai, bu...
# 6   Yeh ibuprofen based hai jo fever aur minor inj...
# 7   Yeh aspirin effervescent form mein hai, fever ...
# 8   Yeh low dose aspirin fever prevention aur hear...
# 9   Yeh combo dawa fever aur muscle pain ko target...
# 10     Yeh fast acting paracetamol fever ke liye hai.
# 11  Yeh NSAID dawa fever aur arthritis pain mein u...
# 12  Yeh dawa serious fungal infections ke liye hai...
# 13  Yeh invasive fungal infections ke liye hospita...
# 14  Yeh modern antifungal cream hai, ringworm aur ...
#
#                                              filter_2  \
# 0   Category: Antipyretics | Symptoms: High fever,...
# 1   Category: Antipyretics | Symptoms: Fever, mild...
# 2   Category: Antipyretics | Symptoms: Fever with ...
# 3   Category: Antipyretics | Symptoms: High fever,...
# 4   Category: Antipyretics | Symptoms: Pulsating h...
# 5   Category: Antipyretics | Symptoms: Severe feve...
# 6   Category: Antipyretics | Symptoms: Fever with ...
# 7   Category: Antipyretics | Symptoms: Fever, naus...
# 8   Category: Antipyretics | Symptoms: Low fever, ...
# 9   Category: Antipyretics | Symptoms: Fever with ...
# 10  Category: Antipyretics | Symptoms: Sudden feve...
# 11  Category: Antipyretics | Symptoms: Fever with ...
# 12  Category: Antifungals | Symptoms: Fever, fatig...
# 13  Category: Antifungals | Symptoms: Fever, chill...
# 14  Category: Antifungals | Symptoms: Red circular...
#
#                                              filter_3  \
# 0   Yeh dawa fever ko kam karti hai aur dard se re...
# 1   Yeh dawa fever aur heart problems ke liye use ...
# 2   Yeh dawa period pain aur fever ke liye best ha...
# 3   Yeh combo dawa fever aur severe pain ko handle...
# 4   Yeh headache aur fever ke liye fast acting daw...
# 5   Yeh strong dawa fever aur pain ke liye hai, bu...
# 6   Yeh ibuprofen based hai jo fever aur minor inj...
# 7   Yeh aspirin effervescent form mein hai, fever ...
# 8   Yeh low dose aspirin fever prevention aur hear...
# 9   Yeh combo dawa fever aur muscle pain ko target...
# 10     Yeh fast acting paracetamol fever ke liye hai.
# 11  Yeh NSAID dawa fever aur arthritis pain mein u...
# 12  Yeh dawa serious fungal infections ke liye hai...
# 13  Yeh invasive fungal infections ke liye hospita...
# 14  Yeh modern antifungal cream hai, ringworm aur ...
#
#                                    embedding_filter_2  \
# 0   [-0.0005164753529243171, 0.010079099796712399,...
# 1   [0.007953549735248089, 0.006598132662475109, -...
# 2   [0.015626205131411552, 0.020940028131008148, -...
# 3   [-0.01105631422251463, 0.018960904330015182, -...
# 4   [0.01026721578091383, 0.023034201934933662, -0...
# 5   [0.004354293458163738, 0.019395075738430023, -...
# 6   [0.0064934128895401955, 0.020966701209545135, ...
# 7   [0.014896235428750515, 0.023116694763302803, -...
# 8   [0.006373646669089794, 0.008612905628979206, -...
# 9   [0.007465155329555273, 0.027585430070757866, -...
# 10  [0.0006729355663992465, 0.016199061647057533, ...
# 11  [-0.00387113681063056, 0.03130008652806282, -0...
# 12  [0.013694584369659424, 0.026703760027885437, -...
# 13  [0.015320118516683578, 0.02137633040547371, -0...
# 14  [0.013400890864431858, 0.018267393112182617, -...
#
#                                    embedding_filter_3  relevance_score
# 0   [0.023296838626265526, 0.05303220450878143, 0....              NaN
# 1   [0.017552271485328674, 0.04074303060770035, 0....              NaN
# 2   [0.01530657522380352, 0.04855331778526306, -0....              NaN
# 3   [0.03484959527850151, 0.051248420029878616, 0....              NaN
# 4   [0.020141560584306717, 0.04811226949095726, 0....              NaN
# 5   [0.00413062609732151, 0.04824482649564743, 0.0...              NaN
# 6   [0.0195281021296978, 0.04020925611257553, -0.0...              NaN
# 7   [0.002894570119678974, 0.0480383075773716, 0.0...              NaN
# 8   [-0.002623590873554349, 0.042069289833307266, ...              NaN
# 9   [0.021629225462675095, 0.048764921724796295, -...              NaN
# 10  [-0.004839485045522451, 0.02840380184352398, 0...              NaN
# 11  [0.011190719902515411, 0.042717333883047104, 0...              NaN
# 12  [0.02654959447681904, 0.057881616055965424, 0....              NaN
# 13  [0.018350699916481972, 0.052447013556957245, -...              NaN
# 14  [0.00265946495346725, 0.0625079870223999, 0.01...              NaN
